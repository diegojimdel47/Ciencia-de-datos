# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
df = pd.read_csv("Tema11.csv")
print("Datos base:\n", df)
# Out:
# Datos base:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0            1  230.1   37.8       69.2   22.1
# 1            2   44.5   39.3       45.1   10.4
# 2            3   17.2   45.9       69.3    9.3
# 3            4  151.5   41.3       58.5   18.5
# 4            5  180.8   10.8       58.4   12.9
# 5            6    8.7   48.9       75.0    7.2
# 6            7   57.5   32.8       23.5   11.8
# 7            8  120.2   19.6       11.6   13.2
# 8            9    8.6    2.1        1.0    4.8
# 9           10  199.8    2.6       21.2   10.6
# 10          11   66.1    5.8       24.2    8.6
# 11          12  214.7   24.0        4.0   17.4
# 12         123   23.8   35.1       65.9    9.2
# 13          14   97.5    7.6        7.2    9.7
# 14          15  204.1   32.9       46.0   19.0
# 15          16  195.4   47.7       52.9   22.4
# 16          17   67.8   36.6      114.0   12.5
# 17          18  281.4   39.6       55.8   24.4
# 18          19   69.2   20.5       18.3   11.3
# ...

# %%
df_corr = df.corr(method="pearson")
print("Coeficiente de correlación de Pearson:", df_corr)
# Out:
# Coeficiente de correlación de Pearson:             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000 -0.018896 -0.098764  -0.022151 -0.100538
# TV           -0.018896  1.000000 -0.091550  -0.193106  0.773471
# Radio        -0.098764 -0.091550  1.000000   0.671995  0.444489
# Newspaper    -0.022151 -0.193106  0.671995   1.000000  0.154691
# Sales        -0.100538  0.773471  0.444489   0.154691  1.000000

# %%
plt.matshow(df_corr)

# %%
plt.plot(df["TV"], df["Sales"], "ro")
plt.ylabel("Ventas")
plt.xlabel("Tv")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df["Radio"], df["Sales"], "ro")
plt.ylabel("Ventas")
plt.xlabel("Radio")
plt.show()

# %%
plt.plot(df["Newspaper"], df["Sales"], "ro")
plt.xlabel("Ventas")
plt.ylabel("Periódico")
plt.show()
