# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import statsmodels.api as smf

# %%
peso = [84, 73, 65, 70, 76, 69, 63, 72, 79, 75, 72, 89, 65, 57, 59, 69, 60, 79, 60, 79, 60, 79, 79, 60, 79]
edad = [46, 20, 52, 30, 57, 25, 28, 36, 57, 44, 24, 31, 52, 23, 60, 48, 34, 51, 50, 34, 46, 23, 37, 40, 30]
grasas = [354, 190, 405, 263, 451, 302, 288, 385, 402, 365, 209, 290, 346, 254, 395, 434, 220, 374, 308, 220, 311, 181, 274, 303, 244]
df = pd.DataFrame({'peso': peso, 'edad': edad, 'grasas': grasas})
print(df)
# Out:
#     peso  edad  grasas
# 0     84    46     354
# 1     73    20     190
# 2     65    52     405
# 3     70    30     263
# 4     76    57     451
# 5     69    25     302
# 6     63    28     288
# 7     72    36     385
# 8     79    57     402
# 9     75    44     365
# 10    72    24     209
# 11    89    31     290
# 12    65    52     346
# 13    57    23     254
# 14    59    60     395
# 15    69    48     434
# 16    60    34     220
# 17    79    51     374
# 18    60    50     308
# 19    79    34     220
# 20    60    46     311
# 21    79    23     181
# 22    79    37     274
# 23    60    40     303
# 24    79    30     244

# %%
fig, ax = plt.subplots(figsize = (6, 3.84))
df.plot(
    x = 'edad',
    y = 'grasas',
    c = 'firebrick',
    kind = 'scatter',
    ax = ax
)

ax.set_title('Distribución de edad y grasas')
# Out:
# Text(0.5, 1.0, 'Distribución de edad y grasas')

# %%
corr_test = pearsonr(x = df['edad'], y = df['grasas'])
print("Coeficiente de correlación de Pearson: ", corr_test[0])
print("P-value: ", corr_test)
# Out:
# Coeficiente de correlación de Pearson:  0.8373533843227795
# P-value:  PearsonRResult(statistic=np.float64(0.8373533843227795), pvalue=np.float64(1.7941010997931788e-07))

# %%
x = df
y = df
x_train, x_test, y_train, y_test = train_test_split(
    x.values.reshape(-1, 1),
    y.values.reshape(-1, 1),
    train_size = 0.8,
    random_state = 1234,
    shuffle = True
)
